# %%
from IPython.display import Image
Image(filename='review_lec.jpg')

# %%
# Hypothesis Testing:
Image(filename='server_failure.png')

# %%
Image(filename='error_types.jpg')

# %%
# Bayesian posterior inference: Explain Bayes’ Rule.  
# Write some code to actually perform posterior sampling.  
# Work out an example using conjugate priors.  
# How does this compare with hypothesis testing?  What are the underlying assumptions?

# %%
# %%latex
# \begin{align}
# P(A\mid B)={\frac {P(B\mid A)\,P(A)}{P(B)}}
# \end{align}
# Out:
# \begin{align}
# P(A\mid B)={\frac {P(B\mid A)\,P(A)}{P(B)}}
# \end{align}

# %%
#
